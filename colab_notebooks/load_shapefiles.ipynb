# %% [markdown]
# <a href="https://colab.research.google.com/github/casto1223/greenspace-impacts/blob/main/colab_notebooks/load_shapefiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Trying to load ParkServe shapefiles

# %% [markdown]
# installing dependencies (chatgpt recommended packages idk)

# %%
# !apt-get install -y libspatialindex-dev
# !pip install geopandas shapely fiona pyproj rtree folium mapclassify
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libspatialindex-c6 libspatialindex6
# The following NEW packages will be installed:
#   libspatialindex-c6 libspatialindex-dev libspatialindex6
# 0 upgraded, 3 newly installed, 0 to remove and 41 not upgraded.
# Need to get 319 kB of archives.
# After this operation, 1,416 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspatialindex6 amd64 1.9.3-2 [247 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspatialindex-c6 amd64 1.9.3-2 [55.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspatialindex-dev amd64 1.9.3-2 [16.0 kB]
# Fetched 319 kB in 2s (194 kB/s)
# Selecting previously unselected package libspatialindex6:amd64.
# (Reading database ... 121713 files and directories currently installed.)
# ...

# %% [markdown]
# mount to google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# make sure using the correct path

# %%
import os
os.listdir("/content/drive/MyDrive/Greenspaces")
# Out:
# ['load_shapefiles',
#  'Parkserve_Shapefiles_05212025.zip',
#  'CPF_DataTables_2010_2025',
#  'Parkscore_2025_DataDownloads_GDB_05212025',
#  'Midpoint Presentation Video.mp4']

# %% [markdown]
# extract to parkserve folder

# %%
import geopandas as gpd
parkServe_shp_zip_path = "/content/drive/MyDrive/Greenspaces/Parkserve_Shapefiles_05212025.zip"
# this path to MyDrive is specific to me, where I made a shortcut to the Greenspaces folder
extract_dst = "/content/parkserve"

import zipfile
with zipfile.ZipFile(parkServe_shp_zip_path, "r") as z:
    z.extractall(extract_dst)

# %% [markdown]
# check it is indeed extracted correctly

# %%
print(os.listdir("/content/parkserve"))
print(os.listdir("/content/parkserve/ParkScore_2025_DataDownloads_shapefiles05212025"))
print(os.listdir("/content/parkserve/ParkScore_2025_DataDownloads_shapefiles05212025/data")) # this is the folder to use
# Out:
# ['ParkScore_2025_DataDownloads_shapefiles05212025']
# ['data', 'ParkServeFields.xlsx']
# ...

# %% [markdown]
# read it

# %%
parkServe = gpd.read_file("/content/parkserve/ParkScore_2025_DataDownloads_shapefiles05212025/data")
# Out:
# /usr/local/lib/python3.12/dist-packages/pyogrio/geopandas.py:275: UserWarning: More than one layer found in 'data': 'ParkServe_Playgrounds' (default), 'ParkServe_Places_Statistics', 'Parkserve_ParkPriorityAreas', 'ParkServe_10MWServiceAreas', 'ParkServe_Parks_Statistics', 'ParkServe_Roads_Trails', 'ParkServe_Parks'. Specify layer parameter to avoid this warning.
#   result = read_func(

# %% [markdown]
# I think we need to somehow compose our findings into one big csv or something so we can analyize them all together
